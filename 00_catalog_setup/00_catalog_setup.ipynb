-- %%
%python
# Databricks notebook source
# MAGIC %md
# MAGIC # 00 · Catalog & Environment Setup
# MAGIC ### Open-Meteo Weather Pipeline
# MAGIC **Run this notebook once before anything else.**
# MAGIC It creates the catalog, all schemas, and all base tables.
